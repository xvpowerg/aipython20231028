# %% [markdown]
# # 這個單元說明基本Python語法
# ## print 語法
#
# print(輸出)

# %%
print("你好!")
# Out:
# 你好!

# %% [markdown]
# ## 貼圖測試
# ![Donut.png](attachment:Donut.png)

# %% [markdown]
# ## latex
# $$E=mc^2$$
# $$\epsilon$$
# $$\lambda$$
# $$\mu$$
# $$\Sigma$$
# $$\beta$$

# %% [markdown]
# ## 變數分配

# %%
'''
Date:2023-10-28
功能:測試變數
'''
a = 1.34
print(a)#輸出變數
#if = 25 #這是關鍵字無法宣告變數
#print(b)#因為b沒有宣告
你好 = "Hello!"
print(你好)
# Out:
# 1.34
# Hello!

# %%
opendex = 100
print(opendex)
opendex = "Ken"
print(opendex)
opendex = 20,"Vivin"
print(opendex)
# Out:
# 100
# Ken
# (20, 'Vivin')

# %%
a1 = 23
print(type(a1))
a1 = "ABC"
print(type(a1))
print(a1.__class__)
a1 = 10,"Lucy"
print(type(a1))

a2 = 10
b1 = a2*10
print(b1)

a2 = "Hello"
b1 = a2 * 10 #10個Hello
print(b1)
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'tuple'>
# 100
# HelloHelloHelloHelloHelloHelloHelloHelloHelloHello

# %%
a = 10
b = 3.14
c = "test"
print(a,b,c)
a2,b2,c2 = 20,"Lucy",3.56
print(a2,b2,c2)
# Out:
# 10 3.14 test
# 20 Lucy 3.56

# %%
v1 = 20
v2 = 30
print("v1:",v1,"v2:",v2)
tmp = v1
v1 = v2
v2 = tmp
print("v1:",v1,"v2:",v2)
# Out:
# v1: 20 v2: 30
# v1: 30 v2: 20

# %%
b1 = 25
b2 = 36
print("b1:",b1,"b2:",b2)
b1,b2 = b2,b1
print("b1:",b1,"b2:",b2)
# Out:
# b1: 25 b2: 36
# b1: 36 b2: 25

# %%
x=y=z=0
print(x,y,z)
# Out:
# 0 0 0

# %%
year = 28
str1 = "你的"
str2 = "年齡是"
print(str1,str2,year,sep="")
title = str1 + str2#字串與字串可用+結合
print(title,year,sep="")
msg = title + str(year)#str(x)把x轉字串
print(msg)
# Out:
# 你的年齡是28
# 你的年齡是28
# 你的年齡是28

# %%
test = ("abc"+"!")*2
print(test)
# Out:
# abc!abc!

# %%
x,y,z = 3,6,9
print(x,y,z)
del y
print(x,z)
print(y)
# Out:
# 3 6 9
# 3 9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 del y
#       4 print(x,z)
# ----> 5 print(y)
#
# NameError: name 'y' is not defined

# %%
a,b = 10,3
print(a + b)
print(a - b)
print(a * b)
#round(a / b, 2)#取到小數點第二位
print(a / b)#會有小數點
print(a // b)#只取商數
print(a % b)#取餘數
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
